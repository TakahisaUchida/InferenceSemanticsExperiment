# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
#from matplotlib import pyplot
import nltk

np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=6)

import csv

import scipy
from scipy import stats
from scipy.stats import pearsonr

from numpy import genfromtxt

from sklearn.linear_model import LinearRegression

from adjustText import adjust_text


def cos_sim(v1, v2):
	return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
data_metusalem = []

#metusalem2012_experiment-glove_6B_50d_twitter
#metusalem2012_experiment-en_core_web_lg
#data = genfromtxt('metusalem2012_glove_6B_100d_reservoir.csv', delimiter=',')
#data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-glove-wiki100.csv', delimiter=','))?
##data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-glove_6B_100d.csv', delimiter=','))
##data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-glove_6B_50d_twitter.csv', delimiter=','))
##data_metusalem_word2vec.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-en_core_web_lg.csv', delimiter=','))
##data_metusalem_word2vec.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment.csv', delimiter=','))
#data_w2v5 = genfromtxt('../embeddingsExperiments/metusalem2012_experiment - wi2v-500-taka.csv', delimiter=',')
##data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-glove_6B_50d_twitter200.csv', delimiter=','))
#data_japan = genfromtxt('../embeddingsExperiments/metusalem2012_experiment_japanese_20200710.csv', delimiter=',')
#data_japan300 = genfromtxt('../embeddingsExperiments/takahisa-w2v300/metusalem2012_experiment_japanese_300d.csv', delimiter=',')
##data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-google300d.csv', delimiter=','))

#data_twit, data_twit200, data_wiki, data_lg, data_w2v, data_google300

data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_100d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_300d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_500d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_nolg_100d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_nolg_300d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_nolg_500d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_win10_100d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_win10_300d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_win10_500d.csv', delimiter=','))

data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-en_core_web_lg.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-en_core_web_md.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-en_core_web_sm.csv', delimiter=','))

data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-fasttext-wiki-news-subwords-300.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-word2vec-google-news-300.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-50.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-100.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-200.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-300.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-25.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-50.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-100.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-200.csv', delimiter=','))

#metusalem2012_experiment-google300d
#metusalem2012_experiment - wi2v-500-taka
#metusalem2012_experiment-glove_6B_50d_twitter200

print(len(data_metusalem))



data_metusalem_bert = []

data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-bert-base.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-bert-base-cls-pooling.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-bert-base-max-pooling.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-bert-large.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-bert-large-cls-pooling.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-bert-large-max-pooling.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-distilbert-base.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-distilbert-base-max-pooling.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-distilroberta-base-v2.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-mpnet-base-v2.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-roberta-base.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-roberta-base-v2.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_nli-roberta-large.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_paraphrase-distilroberta-base-v1.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_paraphrase-xlm-r-multilingual-v1.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-bert-base.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-bert-large.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-distilbert-base.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-distilroberta-base-v2.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-mpnet-base-v2.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-roberta-base.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-roberta-base-v2.csv', delimiter=','))
data_metusalem_bert.append(genfromtxt('../BERTexperiments/metusalem2012_experiment_bert_stsb-roberta-large.csv', delimiter=','))

print(len(data_metusalem_bert))
# Out:
# 22
# 23

# %%
# Metusalem Inference

# this is the main statistic, looking at the impact of discourse on UR vs UU
##print('twit: for BC vs EF',stats.ttest_rel(data_twit[:,1] - data_twit[:,2] , data_twit[:,4] - data_twit[:,5] ))
##print('twit200: for BC vs EF',stats.ttest_rel(data_twit200[:,1] - data_twit200[:,2] , data_twit200[:,4] - data_twit200[:,5] ))
##print('glove100: for BC vs EF',stats.ttest_rel(data_wiki[:,1] - data_wiki[:,2] , data_wiki[:,4] - data_wiki[:,5] ))
##print('spacey-lg-300: for BC vs EF',stats.ttest_rel(data_lg[:,1] - data_lg[:,2] , data_lg[:,4] - data_lg[:,5] ))
##print('w2v100: for BC vs EF',stats.ttest_rel(data_w2v[:,1] - data_w2v[:,2] , data_w2v[:,4] - data_w2v[:,5] ))
#data=data_w2v5
#print('w2v500: for BC vs EF',stats.ttest_rel(data[:,1] - data[:,2] , data[:,4] - data[:,5] ))

##print('google300: for BC vs EF',stats.ttest_rel(data_google300[:,1] - data_google300[:,2] , data_google300[:,4] - data_google300[:,5] ))

#data=data_japan
#print('japan-wi2v: for BC vs EF',stats.ttest_rel(data[:,1] - data[:,2] , data[:,4] - data[:,5] ))
#data=data_japan300
#print('japan-wi2v300: for BC vs EF',stats.ttest_rel(data[:,1] - data[:,2] , data[:,4] - data[:,5] ))

#MetusalemInference = [stats.ttest_rel(data_twit[:,1] - data_twit[:,2] , data_twit[:,4] - data_twit[:,5] )[0], stats.ttest_rel(data_twit200[:,1] - data_twit200[:,2] , data_twit200[:,4] - data_twit200[:,5] )[0], stats.ttest_rel(data_wiki[:,1] - data_wiki[:,2] , data_wiki[:,4] - data_wiki[:,5] )[0], stats.ttest_rel(data_lg[:,1] - data_lg[:,2] , data_lg[:,4] - data_lg[:,5] )[0], stats.ttest_rel(data_w2v[:,1] - data_w2v[:,2] , data_w2v[:,4] - data_w2v[:,5] )[0], stats.ttest_rel(data_google300[:,1] - data_google300[:,2] , data_google300[:,4] - data_google300[:,5] )[0]]
##MetusalemInference = [abs(stats.ttest_rel(data_twit[:,1] - data_twit[:,2] , data_twit[:,4] - data_twit[:,5] )[0]), abs(stats.ttest_rel(data_twit200[:,1] - data_twit200[:,2] , data_twit200[:,4] - data_twit200[:,5] )[0]), abs(stats.ttest_rel(data_wiki[:,1] - data_wiki[:,2] , data_wiki[:,4] - data_wiki[:,5] )[0]), abs(stats.ttest_rel(data_lg[:,1] - data_lg[:,2] , data_lg[:,4] - data_lg[:,5] )[0]), abs(stats.ttest_rel(data_w2v[:,1] - data_w2v[:,2] , data_w2v[:,4] - data_w2v[:,5] )[0]), abs(stats.ttest_rel(data_google300[:,1] - data_google300[:,2] , data_google300[:,4] - data_google300[:,5] )[0])]

MetusalemInference = []

for i in range(len(data_metusalem)):
    print('metusalem',i,': for BC vs EF',stats.ttest_rel(data_metusalem[i][:,1] - data_metusalem[i][:,2] , data_metusalem[i][:,4] - data_metusalem[i][:,5] ))

    MetusalemInference.append(abs(stats.ttest_rel(data_metusalem[i][:,1] - data_metusalem[i][:,2] , data_metusalem[i][:,4] - data_metusalem[i][:,5] )[0]))


print(MetusalemInference)
print(len(MetusalemInference))


# this is the main statistic, looking at the impact of discourse on UR vs UU
#print('metusalem_1: for BC vs EF',stats.ttest_rel(data_metusalem_bert_1[:,1] - data_metusalem_bert_1[:,2] , data_metusalem_bert_1[:,4] - data_metusalem_bert_1[:,5] ))
#print('metusalem_2: for BC vs EF',stats.ttest_rel(data_metusalem_bert_2[:,1] - data_metusalem_bert_2[:,2] , data_metusalem_bert_2[:,4] - data_metusalem_bert_2[:,5] ))
#print('metusalem_3: for BC vs EF',stats.ttest_rel(data_metusalem_bert_3[:,1] - data_metusalem_bert_3[:,2] , data_metusalem_bert_3[:,4] - data_metusalem_bert_3[:,5] ))
#print('metusalem_4: for BC vs EF',stats.ttest_rel(data_metusalem_bert_4[:,1] - data_metusalem_bert_4[:,2] , data_metusalem_bert_4[:,4] - data_metusalem_bert_4[:,5] ))
#print('metusalem_5: for BC vs EF',stats.ttest_rel(data_metusalem_bert_5[:,1] - data_metusalem_bert_5[:,2] , data_metusalem_bert_5[:,4] - data_metusalem_bert_5[:,5] ))
#print('metusalem_6: for BC vs EF',stats.ttest_rel(data_metusalem_bert_6[:,1] - data_metusalem_bert_6[:,2] , data_metusalem_bert_6[:,4] - data_metusalem_bert_6[:,5] ))

#MetusalemInference = [stats.ttest_rel(data_twit[:,1] - data_twit[:,2] , data_twit[:,4] - data_twit[:,5] )[0], stats.ttest_rel(data_twit200[:,1] - data_twit200[:,2] , data_twit200[:,4] - data_twit200[:,5] )[0], stats.ttest_rel(data_wiki[:,1] - data_wiki[:,2] , data_wiki[:,4] - data_wiki[:,5] )[0], stats.ttest_rel(data_lg[:,1] - data_lg[:,2] , data_lg[:,4] - data_lg[:,5] )[0], stats.ttest_rel(data_w2v[:,1] - data_w2v[:,2] , data_w2v[:,4] - data_w2v[:,5] )[0], stats.ttest_rel(data_google300[:,1] - data_google300[:,2] , data_google300[:,4] - data_google300[:,5] )[0]]
#MetusalemInference = [abs(stats.ttest_rel(data_twit[:,1] - data_twit[:,2] , data_twit[:,4] - data_twit[:,5] )[0]), abs(stats.ttest_rel(data_twit200[:,1] - data_twit200[:,2] , data_twit200[:,4] - data_twit200[:,5] )[0]), abs(stats.ttest_rel(data_wiki[:,1] - data_wiki[:,2] , data_wiki[:,4] - data_wiki[:,5] )[0]), abs(stats.ttest_rel(data_lg[:,1] - data_lg[:,2] , data_lg[:,4] - data_lg[:,5] )[0]), abs(stats.ttest_rel(data_w2v[:,1] - data_w2v[:,2] , data_w2v[:,4] - data_w2v[:,5] )[0]), abs(stats.ttest_rel(data_google300[:,1] - data_google300[:,2] , data_google300[:,4] - data_google300[:,5] )[0])]
#MetusalemInference_bert = [, abs(stats.ttest_rel(data_metusalem_bert_2[:,1] - data_metusalem_bert_2[:,2] , data_metusalem_bert_2[:,4] - data_metusalem_bert_2[:,5] )[0]), abs(stats.ttest_rel(data_metusalem_bert_3[:,1] - data_metusalem_bert_3[:,2] , data_metusalem_bert_3[:,4] - data_metusalem_bert_3[:,5] )[0]), abs(stats.ttest_rel(data_metusalem_bert_4[:,1] - data_metusalem_bert_4[:,2] , data_metusalem_bert_4[:,4] - data_metusalem_bert_4[:,5] )[0]), abs(stats.ttest_rel(data_metusalem_bert_5[:,1] - data_metusalem_bert_5[:,2] , data_metusalem_bert_5[:,4] - data_metusalem_bert_5[:,5] )[0]), abs(stats.ttest_rel(data_metusalem_bert_6[:,1] - data_metusalem_bert_6[:,2] , data_metusalem_bert_6[:,4] - data_metusalem_bert_6[:,5] )[0])]

MetusalemInference_bert = []

for i in range(len(data_metusalem_bert)):
    print('metusalem_bert',i,': for BC vs EF',stats.ttest_rel(data_metusalem_bert[i][:,1] - data_metusalem_bert[i][:,2] , data_metusalem_bert[i][:,4] - data_metusalem_bert[i][:,5] ))

    MetusalemInference_bert.append(abs(stats.ttest_rel(data_metusalem_bert[i][:,1] - data_metusalem_bert[i][:,2] , data_metusalem_bert[i][:,4] - data_metusalem_bert[i][:,5] )[0]))


print(MetusalemInference_bert)
print(len(MetusalemInference_bert))
# Out:
# metusalem 0 : for BC vs EF Ttest_relResult(statistic=-4.143100747687799, pvalue=9.328642450789364e-05)
# metusalem 1 : for BC vs EF Ttest_relResult(statistic=-4.350838667193691, pvalue=4.458728778658047e-05)
# metusalem 2 : for BC vs EF Ttest_relResult(statistic=-4.516451661997635, pvalue=2.4439296676781328e-05)
# metusalem 3 : for BC vs EF Ttest_relResult(statistic=-4.235581885041527, pvalue=6.730925697208286e-05)
# metusalem 4 : for BC vs EF Ttest_relResult(statistic=-3.9926691835892694, pvalue=0.0001573489338212736)
# metusalem 5 : for BC vs EF Ttest_relResult(statistic=-4.010692545927518, pvalue=0.00014787569005370887)
# metusalem 6 : for BC vs EF Ttest_relResult(statistic=-3.6846273439665844, pvalue=0.0004439691609018965)
# metusalem 7 : for BC vs EF Ttest_relResult(statistic=-4.658037706282229, pvalue=1.4494374710868822e-05)
# metusalem 8 : for BC vs EF Ttest_relResult(statistic=-4.74801812074383, pvalue=1.0359663264239023e-05)
# ...

# %%
# Metusalem Semantics


# NOW compare to a simpler mesure of semantics
##print('twit: for BC vs EF',stats.ttest_rel(data_twit[:,0]  , (data_twit[:,1] + data_twit[:,2])/2 ))
##print('twit200: for BC vs EF',stats.ttest_rel(data_twit200[:,0]  , (data_twit200[:,1] + data_twit200[:,2])/2 ))
##print('glove100: for BC vs EF',stats.ttest_rel(data_wiki[:,0]  , (data_wiki[:,1] + data_wiki[:,2])/2 ))
##print('spacey-lg-300: for BC vs EF',stats.ttest_rel(data_lg[:,0]  , (data_lg[:,1] + data_lg[:,2])/2 ))
##print('w2v100: for BC vs EF',stats.ttest_rel(data_w2v[:,0]  , (data_w2v[:,1] + data_w2v[:,2])/2 ))
#data=data_w2v5
#print('w2v500: for BC vs EF',stats.ttest_rel(data[:,0]  , (data[:,1] + data[:,2])/2 ))
##print('google300: for BC vs EF',stats.ttest_rel(data_google300[:,0]  , (data_google300[:,1] + data_google300[:,2])/2 ))

##MetusalemSemantics = [stats.ttest_rel(data_twit[:,0]  , (data_twit[:,1] + data_twit[:,2])/2 )[0], stats.ttest_rel(data_twit200[:,0]  , (data_twit200[:,1] + data_twit200[:,2])/2 )[0], stats.ttest_rel(data_wiki[:,0]  , (data_wiki[:,1] + data_wiki[:,2])/2 )[0], stats.ttest_rel(data_lg[:,0]  , (data_lg[:,1] + data_lg[:,2])/2 )[0], stats.ttest_rel(data_w2v[:,0]  , (data_w2v[:,1] + data_w2v[:,2])/2 )[0], stats.ttest_rel(data_google300[:,0]  , (data_google300[:,1] + data_google300[:,2])/2 )[0]]

MetusalemSemantics = []

for i in range(len(data_metusalem)):
    print('data_metusalem',i,': for BC vs EF',stats.ttest_rel(data_metusalem[i][:,0]  , (data_metusalem[i][:,1] + data_metusalem[i][:,2])/2 ))
    
    MetusalemSemantics.append(abs(stats.ttest_rel(data_metusalem[i][:,0]  , (data_metusalem[i][:,1] + data_metusalem[i][:,2])/2 )[0]))
    

print(MetusalemSemantics)
print(len(MetusalemSemantics))



# NOW compare to a simpler mesure of semantics
#print('data_metusalem_1: for BC vs EF',stats.ttest_rel(data_metusalem_bert_1[:,0]  , (data_metusalem_bert_1[:,1] + data_metusalem_bert_1[:,2])/2 ))
#print('data_metusalem_2: for BC vs EF',stats.ttest_rel(data_metusalem_bert_2[:,0]  , (data_metusalem_bert_2[:,1] + data_metusalem_bert_2[:,2])/2 ))
#print('data_metusalem_3: for BC vs EF',stats.ttest_rel(data_metusalem_bert_3[:,0]  , (data_metusalem_bert_3[:,1] + data_metusalem_bert_3[:,2])/2 ))
#print('data_metusalem_4: for BC vs EF',stats.ttest_rel(data_metusalem_bert_4[:,0]  , (data_metusalem_bert_4[:,1] + data_metusalem_bert_4[:,2])/2 ))
#print('data_metusalem_5: for BC vs EF',stats.ttest_rel(data_metusalem_bert_5[:,0]  , (data_metusalem_bert_5[:,1] + data_metusalem_bert_5[:,2])/2 ))
#print('data_metusalem_6: for BC vs EF',stats.ttest_rel(data_metusalem_bert_6[:,0]  , (data_metusalem_bert_6[:,1] + data_metusalem_bert_6[:,2])/2 ))

MetusalemSemantics_bert = []

for i in range(len(data_metusalem_bert)):
    print('data_metusalem_bert',i,': for BC vs EF',stats.ttest_rel(data_metusalem_bert[i][:,0]  , (data_metusalem_bert[i][:,1] + data_metusalem_bert[i][:,2])/2 ))
    
    MetusalemSemantics_bert.append(abs(stats.ttest_rel(data_metusalem_bert[i][:,0]  , (data_metusalem_bert[i][:,1] + data_metusalem_bert[i][:,2])/2 )[0]))
    
#MetusalemSemantics_bert = [stats.ttest_rel(data_metusalem_bert_1[:,0]  , (data_metusalem_bert_1[:,1] + data_metusalem_bert_1[:,2])/2 )[0], stats.ttest_rel(data_metusalem_bert_2[:,0]  , (data_metusalem_bert_2[:,1] + data_metusalem_bert_2[:,2])/2 )[0], stats.ttest_rel(data_metusalem_bert_3[:,0]  , (data_metusalem_bert_3[:,1] + data_metusalem_bert_3[:,2])/2 )[0], stats.ttest_rel(data_metusalem_bert_4[:,0]  , (data_metusalem_bert_4[:,1] + data_metusalem_bert_4[:,2])/2 )[0], stats.ttest_rel(data_metusalem_bert_5[:,0]  , (data_metusalem_bert_5[:,1] + data_metusalem_bert_5[:,2])/2 )[0], stats.ttest_rel(data_metusalem_bert_6[:,0]  , (data_metusalem_bert_6[:,1] + data_metusalem_bert_6[:,2])/2 )[0]]

print(MetusalemSemantics_bert)
print(len(MetusalemSemantics_bert))
# Out:
# data_metusalem 0 : for BC vs EF Ttest_relResult(statistic=6.595083760811229, pvalue=6.433594054819778e-09)
# data_metusalem 1 : for BC vs EF Ttest_relResult(statistic=6.335064255049253, pvalue=1.8976778185322564e-08)
# data_metusalem 2 : for BC vs EF Ttest_relResult(statistic=6.451047357780633, pvalue=1.1727021820357226e-08)
# data_metusalem 3 : for BC vs EF Ttest_relResult(statistic=6.990718728825909, pvalue=1.2211911524251194e-09)
# data_metusalem 4 : for BC vs EF Ttest_relResult(statistic=6.92701717332822, pvalue=1.5975528499899837e-09)
# data_metusalem 5 : for BC vs EF Ttest_relResult(statistic=7.3528180326574395, pvalue=2.6355917286838515e-10)
# data_metusalem 6 : for BC vs EF Ttest_relResult(statistic=6.429702613295901, pvalue=1.2815070451085722e-08)
# data_metusalem 7 : for BC vs EF Ttest_relResult(statistic=6.670241635248498, pvalue=4.698318013685873e-09)
# data_metusalem 8 : for BC vs EF Ttest_relResult(statistic=6.5432487556870695, pvalue=7.987726911114726e-09)
# ...

# %%
# McKoon Inference

data_mckoon = []

#data = genfromtxt('../McKoon1986-pipeline/McKoon_experiment.csv', delimiter=',')
##data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en-wiki100d.csv', delimiter=','))
##data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en_core_web_lg.csv', delimiter=','))
##data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove_6B_100d.csv', delimiter=','))
##data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-twitter-small.csv', delimiter=','))
##data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-twitter.csv', delimiter=','))
##data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-google.csv', delimiter=','))


data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_100d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_300d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_500d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_nolg_100d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_nolg_300d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_nolg_500d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_win10_100d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_win10_300d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_win10_500d.csv', delimiter=','))

data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en_core_web_lg.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en_core_web_md.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en_core_web_sm.csv', delimiter=','))

data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-fasttext-wiki-news-subwords-300.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-word2vec-google-news-300.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-50.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-100.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-200.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-300.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-25.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-50.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-100.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-200.csv', delimiter=','))


print(len(data_mckoon))


#wiki100, google300, twitter200, Twitter50, spacey-large, glove100

data_mckoon_bert = []

data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-bert-base.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-bert-base-cls-pooling.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-bert-base-max-pooling.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-bert-large.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-bert-large-cls-pooling.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-bert-large-max-pooling.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-distilbert-base.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-distilbert-base-max-pooling.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-distilroberta-base-v2.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-mpnet-base-v2.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-roberta-base.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-roberta-base-v2.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_nli-roberta-large.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_paraphrase-distilroberta-base-v1.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_paraphrase-xlm-r-multilingual-v1.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-bert-base.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-bert-large.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-distilbert-base.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-distilroberta-base-v2.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-mpnet-base-v2.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-roberta-base.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-roberta-base-v2.csv', delimiter=','))
data_mckoon_bert.append(genfromtxt('../BERTexperiments/McKoon_experiment_bert_stsb-roberta-large.csv', delimiter=','))

print(len(data_mckoon_bert))
# Out:
# 22
# 23

# %%
##print('wiki2vec100-old: ', stats.ttest_rel(data[:,0], data[:,1]))
#print('twitter50:   ', stats.ttest_rel(data4[:,0], data4[:,1]))
#print('twitter200:  ', stats.ttest_rel(data3[:,0], data3[:,1]))
#print('glove_6B_100d:   ', stats.ttest_rel(data6[:,0], data6[:,1]))
#print('core_web_lg:  ', stats.ttest_rel(data5[:,0], data5[:,1]))
#print('wiki2vec100-verify: ', stats.ttest_rel(data1[:,0], data1[:,1]))#data[:,1]->data1?
#print('google300:   ', stats.ttest_rel(data2[:,0], data2[:,1]))


McKoonInference = []

for i in range(len(data_mckoon)):
    print('data_mckoon',i,':', stats.ttest_rel(data_mckoon[i][:,0], data_mckoon[i][:,1]))

    McKoonInference.append(abs(stats.ttest_rel(data_mckoon[i][:,0], data_mckoon[i][:,1])[0]))


#McKoonInference = [stats.ttest_rel(data4[:,0], data4[:,1])[0], stats.ttest_rel(data3[:,0], data3[:,1])[0], stats.ttest_rel(data6[:,0], data6[:,1])[0], stats.ttest_rel(data5[:,0], data5[:,1])[0], stats.ttest_rel(data1[:,0], data1[:,1])[0], stats.ttest_rel(data2[:,0], data2[:,1])[0]]

print(McKoonInference)
print(len(McKoonInference))




#print('data_mckoon_1:   ', stats.ttest_rel(data_mckoon_bert_1[:,0], data_mckoon_bert_1[:,1]))
#print('data_mckoon_2:  ', stats.ttest_rel(data_mckoon_bert_2[:,0], data_mckoon_bert_2[:,1]))
#print('data_mckoon_3:   ', stats.ttest_rel(data_mckoon_bert_3[:,0], data_mckoon_bert_3[:,1]))
#print('data_mckoon_4:  ', stats.ttest_rel(data_mckoon_bert_4[:,0], data_mckoon_bert_4[:,1]))
#print('data_mckoon_5: ', stats.ttest_rel(data_mckoon_bert_5[:,0], data_mckoon_bert_5[:,1]))
#print('data_mckoon_6:   ', stats.ttest_rel(data_mckoon_bert_6[:,0], data_mckoon_bert_6[:,1]))

#McKoonInference_bert = [, stats.ttest_rel(data_mckoon_bert_2[:,0], data_mckoon_bert_2[:,1])[0], stats.ttest_rel(data_mckoon_bert_3[:,0], data_mckoon_bert_3[:,1])[0], stats.ttest_rel(data_mckoon_bert_4[:,0], data_mckoon_bert_4[:,1])[0], stats.ttest_rel(data_mckoon_bert_5[:,0], data_mckoon_bert_5[:,1])[0], stats.ttest_rel(data_mckoon_bert_6[:,0], data_mckoon_bert_6[:,1])[0]]

McKoonInference_bert = []

for i in range(len(data_mckoon_bert)):
    print('data_mckoon_bert',i,':', stats.ttest_rel(data_mckoon_bert[i][:,0], data_mckoon_bert[i][:,1]))

    McKoonInference_bert.append(abs(stats.ttest_rel(data_mckoon_bert[i][:,0], data_mckoon_bert[i][:,1])[0]))

print(McKoonInference_bert)
print(len(McKoonInference_bert))
# Out:
# data_mckoon 0 : Ttest_relResult(statistic=2.1440930451971427, pvalue=0.03997748462492251)
# data_mckoon 1 : Ttest_relResult(statistic=2.386736106312513, pvalue=0.02328582588164981)
# data_mckoon 2 : Ttest_relResult(statistic=1.851762413547763, pvalue=0.07360558354119749)
# data_mckoon 3 : Ttest_relResult(statistic=2.1826540441104103, pvalue=0.03675920648893078)
# data_mckoon 4 : Ttest_relResult(statistic=2.249322202636618, pvalue=0.03173760683422)
# data_mckoon 5 : Ttest_relResult(statistic=2.1564728767628822, pvalue=0.03891793584201613)
# data_mckoon 6 : Ttest_relResult(statistic=2.674295629003953, pvalue=0.011844126429238239)
# data_mckoon 7 : Ttest_relResult(statistic=2.315977610100544, pvalue=0.027342325220756084)
# data_mckoon 8 : Ttest_relResult(statistic=2.0779747800837884, pvalue=0.04608203509259067)
# data_mckoon 9 : Ttest_relResult(statistic=2.6783214213038278, pvalue=0.011729610520715267)
# ...

# %%
ChwillaSemantics = []

ChwillaSemantics_csvFile =[
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_100d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_300d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_500d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_nolg_100d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_nolg_300d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_nolg_500d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_win10_100d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_win10_300d',
    'ttest_ind-WIKIPEDIA2VEC-enwiki_20180420_win10_500d',
    'ttest_ind-SPACY-en_core_web_lg',
    'ttest_ind-SPACY-en_core_web_md',
    'ttest_ind-SPACY-en_core_web_sm',
    'ttest_ind-GENSIM-fasttext-wiki-news-subwords-300',
    'ttest_ind-GENSIM-word2vec-google-news-300',
    'ttest_ind-GENSIM-glove-wiki-gigaword-50',
    'ttest_ind-GENSIM-glove-wiki-gigaword-100',
    'ttest_ind-GENSIM-glove-wiki-gigaword-200',
    'ttest_ind-GENSIM-glove-wiki-gigaword-300',
    'ttest_ind-GENSIM-glove-twitter-25',
    'ttest_ind-GENSIM-glove-twitter-50',
    'ttest_ind-GENSIM-glove-twitter-100',
    'ttest_ind-GENSIM-glove-twitter-200'    
]
print(len(ChwillaSemantics_csvFile))

for csvFile in ChwillaSemantics_csvFile:
    with open('../ChwillaTest/' + csvFile + '.csv') as f_chwilla:
        reader = csv.reader(f_chwilla)
        l = [row for row in reader]
        print(float(l[0][1]))
        ChwillaSemantics.append(float(l[0][0]))

print(ChwillaSemantics)



ChwillaSemantics_bert = []

ChwillaSemantics_bert_csvFile =[
    'ttest_ind-BERT-nli-bert-base',
    'ttest_ind-BERT-nli-bert-base-cls-pooling',
    'ttest_ind-BERT-nli-bert-base-max-pooling',
    'ttest_ind-BERT-nli-bert-large',
    'ttest_ind-BERT-nli-bert-large-cls-pooling',
    'ttest_ind-BERT-nli-bert-large-max-pooling',
    'ttest_ind-BERT-nli-distilbert-base',
    'ttest_ind-BERT-nli-distilbert-base-max-pooling',
    'ttest_ind-BERT-nli-distilroberta-base-v2',
    'ttest_ind-BERT-nli-mpnet-base-v2',
    'ttest_ind-BERT-nli-roberta-base',
    'ttest_ind-BERT-nli-roberta-base-v2',
    'ttest_ind-BERT-nli-roberta-large',
    'ttest_ind-BERT-paraphrase-distilroberta-base-v1',
    'ttest_ind-BERT-paraphrase-xlm-r-multilingual-v1',
    'ttest_ind-BERT-stsb-bert-base',
    'ttest_ind-BERT-stsb-bert-large',
    'ttest_ind-BERT-stsb-distilbert-base',
    'ttest_ind-BERT-stsb-distilroberta-base-v2',
    'ttest_ind-BERT-stsb-mpnet-base-v2',
    'ttest_ind-BERT-stsb-roberta-base',
    'ttest_ind-BERT-stsb-roberta-base-v2',
    'ttest_ind-BERT-stsb-roberta-large'
]
print(len(ChwillaSemantics_bert_csvFile))

for csvFile_bert in ChwillaSemantics_bert_csvFile:
    with open('../BERTexperiments/' + csvFile_bert + '.csv') as f_chwilla_bert:
        reader_bert = csv.reader(f_chwilla_bert)
        l_bert = [row for row in reader_bert]
        print(float(l_bert[0][1]))
        ChwillaSemantics_bert.append(float(l_bert[0][0]))

print(ChwillaSemantics_bert)
# Out:
# 22
# 3.5504209260762395e-18
# 5.608933187016611e-17
# 6.432714363434452e-17
# 3.3538259729778307e-18
# 1.1607951098639261e-17
# 9.166745372639515e-17
# 5.5414502379460587e-17
# 7.71665654966264e-17
# 1.338717964326691e-16
# 2.472935250847339e-20
# 1.1967525490153415e-18
# 0.03505396410007076
# 1.6764040626235416e-19
# 8.267267787700706e-19
# 1.7923196612552711e-16
# 1.8993891858514992e-17
# 5.969428208821424e-19
# 2.4462998613588405e-18
# 1.0483839844824934e-06
# 7.132807022164759e-09
# 1.6864058759115544e-10
# 2.782136791868171e-11
# [11.343150764086925, 10.707682647015274, 10.676344511337, 11.356360061473627, 11.069336019047514, 10.59543371441052, 10.710451630301614, 10.634756237796864, 10.509053544006727, 12.511401155249875, 11.596023192223004, 2.1451335054702745, 12.05708451704348, 11.682385574035592, 10.442589709547352, 10.955993854910213, 11.758570460422087, 11.429599204790996, 5.2994016481919015, 6.493174607286894, 7.350246984185086, 7.756628295946341]
# 23
# ...

# %%
print("pearsonr(ChwillaSemantics, MetusalemInference)")
print(pearsonr(ChwillaSemantics, MetusalemInference))
print("pearsonr(ChwillaSemantics, McKoonInference)")
print(pearsonr(ChwillaSemantics, McKoonInference))

print("pearsonr(ChwillaSemantics_bert, MetusalemInference_bert)")
print(pearsonr(ChwillaSemantics_bert, MetusalemInference_bert))
print("pearsonr(ChwillaSemantics_bert, McKoonInference_bert)")
print(pearsonr(ChwillaSemantics_bert, McKoonInference_bert))

print("pearsonr(ChwillaSemantics, MetusalemSemantics)")
print(pearsonr(ChwillaSemantics, MetusalemSemantics))
print("pearsonr(ChwillaSemantics_bert, MetusalemSemantics_bert)")
print(pearsonr(ChwillaSemantics_bert, MetusalemSemantics_bert))

plt.figure(figsize=[12,8])

plt.scatter(ChwillaSemantics, MetusalemInference, s=200, label='Met-inf Static', color='red')
texts_MetInfStatic = [plt.text(ChwillaSemantics[i], MetusalemInference[i], str(i), ha='center', va='center') for i in range(len(ChwillaSemantics))]
#adjust_text(texts_MetInfStatic)
plt.scatter(ChwillaSemantics, McKoonInference, s=200, label='Mc-inf Static', color='blue')
texts_McInfStatic = [plt.text(ChwillaSemantics[i], McKoonInference[i], str(i), ha='center', va='center') for i in range(len(ChwillaSemantics))]
#adjust_text(texts_McInfStatic)

plt.scatter(ChwillaSemantics_bert, MetusalemInference_bert, s=200, label='Met-inf Context', color='orange')
texts_MetInfContext = [plt.text(ChwillaSemantics_bert[i], MetusalemInference_bert[i], str(i), ha='center', va='center') for i in range(len(ChwillaSemantics_bert))]
plt.scatter(ChwillaSemantics_bert, McKoonInference_bert, s=200, label='Mc-inf Context', color='green')
texts_McInfContext = [plt.text(ChwillaSemantics_bert[i], McKoonInference_bert[i], str(i), ha='center', va='center') for i in range(len(ChwillaSemantics_bert))]

coefficientMetusalem = np.polyfit(ChwillaSemantics, MetusalemInference, 1)
coefficientMcKoon = np.polyfit(ChwillaSemantics, McKoonInference, 1)
print(coefficientMetusalem)
print(coefficientMcKoon)

coefficientMetusalem_bert = np.polyfit(ChwillaSemantics_bert, MetusalemInference_bert, 1)
coefficientMcKoon_bert = np.polyfit(ChwillaSemantics_bert, McKoonInference_bert, 1)
print(coefficientMetusalem_bert)
print(coefficientMcKoon_bert)

plt.plot(ChwillaSemantics, np.poly1d(coefficientMetusalem)(ChwillaSemantics), color='red')
plt.plot(ChwillaSemantics, np.poly1d(coefficientMcKoon)(ChwillaSemantics), color='blue')

plt.plot(ChwillaSemantics_bert, np.poly1d(coefficientMetusalem_bert)(ChwillaSemantics_bert), color='orange')
plt.plot(ChwillaSemantics_bert, np.poly1d(coefficientMcKoon_bert)(ChwillaSemantics_bert), color='green')


plt.xlabel('t-score for Semantics (Chwilla)', fontsize=18)
plt.ylabel('t-score for Inference', fontsize=18)


#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=18)
plt.tight_layout()
plt.savefig('chwilla_analysis.png')
plt.show()
# Out:
# pearsonr(ChwillaSemantics, MetusalemInference)
# (0.879242000190145, 7.165502747921717e-08)
# pearsonr(ChwillaSemantics, McKoonInference)
# (0.6041068490074862, 0.0029064020714013694)
# pearsonr(ChwillaSemantics_bert, MetusalemInference_bert)
# (0.6790715056763466, 0.0003666998871555711)
# pearsonr(ChwillaSemantics_bert, McKoonInference_bert)
# (-0.1342561591245958, 0.5413725013640696)
# pearsonr(ChwillaSemantics, MetusalemSemantics)
# (0.9137376596522582, 2.8733363013213056e-09)
# pearsonr(ChwillaSemantics_bert, MetusalemSemantics_bert)
# (0.596972668730347, 0.0026357485269674023)
# [ 0.493925 -1.229648]
# [0.061638 1.640924]
# [0.572507 1.86969 ]
# [-0.11004   6.026259]
