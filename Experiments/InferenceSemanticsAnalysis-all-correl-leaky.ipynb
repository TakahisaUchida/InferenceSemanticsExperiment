# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
#from matplotlib import pyplot
import nltk

np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=6)

import csv

import scipy
from scipy import stats
from scipy.stats import pearsonr

from numpy import genfromtxt

from sklearn.linear_model import LinearRegression


def cos_sim(v1, v2):
	return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
data_metusalem = []


data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_100d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_300d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_500d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_nolg_100d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_nolg_300d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_nolg_500d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_win10_100d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_win10_300d.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-enwiki_20180420_win10_500d.csv', delimiter=','))

data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-en_core_web_lg.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-en_core_web_md.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-en_core_web_sm.csv', delimiter=','))

data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-fasttext-wiki-news-subwords-300.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-word2vec-google-news-300.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-50.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-100.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-200.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-wiki-gigaword-300.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-25.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-50.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-100.csv', delimiter=','))
data_metusalem.append(genfromtxt('../embeddingsExperiments/metusalem2012_experiment-GENSIM-glove-twitter-200.csv', delimiter=','))


print(len(data_metusalem))


data_metusalem_leaky = []


data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_100d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_300d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_500d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_nolg_100d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_nolg_300d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_nolg_500d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_win10_100d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_win10_300d.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-enwiki_20180420_win10_500d.csv', delimiter=','))

data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-en_core_web_lg.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-en_core_web_md.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-en_core_web_sm.csv', delimiter=','))

data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-fasttext-wiki-news-subwords-300.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-word2vec-google-news-300.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-wiki-gigaword-50.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-wiki-gigaword-100.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-wiki-gigaword-200.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-wiki-gigaword-300.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-twitter-25.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-twitter-50.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-twitter-100.csv', delimiter=','))
data_metusalem_leaky.append(genfromtxt('../embeddingsExperiments/LealyIntegrator-metusalem2012_experiment-GENSIM-glove-twitter-200.csv', delimiter=','))


print(len(data_metusalem_leaky))
# Out:
# 22
# 22

# %%
# Metusalem Inference

MetusalemInference = []

for i in range(len(data_metusalem)):
    print('metusalem',i,': for BC vs EF',stats.ttest_rel(data_metusalem[i][:,1] - data_metusalem[i][:,2] , data_metusalem[i][:,4] - data_metusalem[i][:,5] ))

    MetusalemInference.append(abs(stats.ttest_rel(data_metusalem[i][:,1] - data_metusalem[i][:,2] , data_metusalem[i][:,4] - data_metusalem[i][:,5] )[0]))


print(MetusalemInference)
print(len(MetusalemInference))


MetusalemInference_leaky = []

for i in range(len(data_metusalem_leaky)):
    print('metusalem_leaky',i,': for BC vs EF',stats.ttest_rel(data_metusalem_leaky[i][:,1] - data_metusalem_leaky[i][:,2] , data_metusalem_leaky[i][:,4] - data_metusalem_leaky[i][:,5] ))

    MetusalemInference_leaky.append(abs(stats.ttest_rel(data_metusalem_leaky[i][:,1] - data_metusalem_leaky[i][:,2] , data_metusalem_leaky[i][:,4] - data_metusalem_leaky[i][:,5] )[0]))


print(MetusalemInference_leaky)
print(len(MetusalemInference_leaky))
# Out:
# metusalem 0 : for BC vs EF Ttest_relResult(statistic=-4.143100747687799, pvalue=9.328642450789364e-05)
# metusalem 1 : for BC vs EF Ttest_relResult(statistic=-4.350838667193691, pvalue=4.458728778658047e-05)
# metusalem 2 : for BC vs EF Ttest_relResult(statistic=-4.516451661997635, pvalue=2.4439296676781328e-05)
# metusalem 3 : for BC vs EF Ttest_relResult(statistic=-4.235581885041527, pvalue=6.730925697208286e-05)
# metusalem 4 : for BC vs EF Ttest_relResult(statistic=-3.9926691835892694, pvalue=0.0001573489338212736)
# metusalem 5 : for BC vs EF Ttest_relResult(statistic=-4.010692545927518, pvalue=0.00014787569005370887)
# metusalem 6 : for BC vs EF Ttest_relResult(statistic=-3.6846273439665844, pvalue=0.0004439691609018965)
# metusalem 7 : for BC vs EF Ttest_relResult(statistic=-4.658037706282229, pvalue=1.4494374710868822e-05)
# metusalem 8 : for BC vs EF Ttest_relResult(statistic=-4.74801812074383, pvalue=1.0359663264239023e-05)
# ...

# %%
# Metusalem Semantics

MetusalemSemantics = []

for i in range(len(data_metusalem)):
    print('data_metusalem',i,': for BC vs EF',stats.ttest_rel(data_metusalem[i][:,0]  , (data_metusalem[i][:,1] + data_metusalem[i][:,2])/2 ))
    
    MetusalemSemantics.append(abs(stats.ttest_rel(data_metusalem[i][:,0]  , (data_metusalem[i][:,1] + data_metusalem[i][:,2])/2 )[0]))
    

print(MetusalemSemantics)
print(len(MetusalemSemantics))


MetusalemSemantics_leaky = []

for i in range(len(data_metusalem_leaky)):
    print('data_metusalem_leaky',i,': for BC vs EF',stats.ttest_rel(data_metusalem_leaky[i][:,0]  , (data_metusalem_leaky[i][:,1] + data_metusalem_leaky[i][:,2])/2 ))
    
    MetusalemSemantics_leaky.append(abs(stats.ttest_rel(data_metusalem_leaky[i][:,0]  , (data_metusalem_leaky[i][:,1] + data_metusalem_leaky[i][:,2])/2 )[0]))
    

print(MetusalemSemantics_leaky)
print(len(MetusalemSemantics_leaky))
# Out:
# data_metusalem 0 : for BC vs EF Ttest_relResult(statistic=6.595083760811229, pvalue=6.433594054819778e-09)
# data_metusalem 1 : for BC vs EF Ttest_relResult(statistic=6.335064255049253, pvalue=1.8976778185322564e-08)
# data_metusalem 2 : for BC vs EF Ttest_relResult(statistic=6.451047357780633, pvalue=1.1727021820357226e-08)
# data_metusalem 3 : for BC vs EF Ttest_relResult(statistic=6.990718728825909, pvalue=1.2211911524251194e-09)
# data_metusalem 4 : for BC vs EF Ttest_relResult(statistic=6.92701717332822, pvalue=1.5975528499899837e-09)
# data_metusalem 5 : for BC vs EF Ttest_relResult(statistic=7.3528180326574395, pvalue=2.6355917286838515e-10)
# data_metusalem 6 : for BC vs EF Ttest_relResult(statistic=6.429702613295901, pvalue=1.2815070451085722e-08)
# data_metusalem 7 : for BC vs EF Ttest_relResult(statistic=6.670241635248498, pvalue=4.698318013685873e-09)
# data_metusalem 8 : for BC vs EF Ttest_relResult(statistic=6.5432487556870695, pvalue=7.987726911114726e-09)
# ...

# %%
# McKoon Inference

data_mckoon = []


data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_100d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_300d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_500d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_nolg_100d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_nolg_300d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_nolg_500d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_win10_100d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_win10_300d.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-enwiki_20180420_win10_500d.csv', delimiter=','))

data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en_core_web_lg.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en_core_web_md.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-en_core_web_sm.csv', delimiter=','))

data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-fasttext-wiki-news-subwords-300.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-word2vec-google-news-300.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-50.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-100.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-200.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-wiki-gigaword-300.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-25.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-50.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-100.csv', delimiter=','))
data_mckoon.append(genfromtxt('../McKoon1986-pipeline/McKoon_experiment-glove-twitter-200.csv', delimiter=','))


print(len(data_mckoon))



data_mckoon_leaky = []


data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_100d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_300d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_500d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_nolg_100d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_nolg_300d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_nolg_500d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_win10_100d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_win10_300d.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-enwiki_20180420_win10_500d.csv', delimiter=','))

data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-en_core_web_lg.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-en_core_web_md.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-en_core_web_sm.csv', delimiter=','))

data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-fasttext-wiki-news-subwords-300.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-word2vec-google-news-300.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-wiki-gigaword-50.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-wiki-gigaword-100.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-wiki-gigaword-200.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-wiki-gigaword-300.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-twitter-25.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-twitter-50.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-twitter-100.csv', delimiter=','))
data_mckoon_leaky.append(genfromtxt('../McKoon1986-pipeline/LealyIntegrator-McKoon_experiment-glove-twitter-200.csv', delimiter=','))


print(len(data_mckoon_leaky))
# Out:
# 22
# 22

# %%
McKoonInference = []

for i in range(len(data_mckoon)):
    print('data_mckoon',i,':', stats.ttest_rel(data_mckoon[i][:,0], data_mckoon[i][:,1]))

    McKoonInference.append(abs(stats.ttest_rel(data_mckoon[i][:,0], data_mckoon[i][:,1])[0]))


print(McKoonInference)
print(len(McKoonInference))

McKoonInference_leaky = []

for i in range(len(data_mckoon_leaky)):
    print('data_mckoon_leaky',i,':', stats.ttest_rel(data_mckoon_leaky[i][:,0], data_mckoon_leaky[i][:,1]))

    McKoonInference_leaky.append(abs(stats.ttest_rel(data_mckoon_leaky[i][:,0], data_mckoon_leaky[i][:,1])[0]))


print(McKoonInference_leaky)
print(len(McKoonInference_leaky))
# Out:
# data_mckoon 0 : Ttest_relResult(statistic=2.1440930451971427, pvalue=0.03997748462492251)
# data_mckoon 1 : Ttest_relResult(statistic=2.386736106312513, pvalue=0.02328582588164981)
# data_mckoon 2 : Ttest_relResult(statistic=1.851762413547763, pvalue=0.07360558354119749)
# data_mckoon 3 : Ttest_relResult(statistic=2.1826540441104103, pvalue=0.03675920648893078)
# data_mckoon 4 : Ttest_relResult(statistic=2.249322202636618, pvalue=0.03173760683422)
# data_mckoon 5 : Ttest_relResult(statistic=2.1564728767628822, pvalue=0.03891793584201613)
# data_mckoon 6 : Ttest_relResult(statistic=2.674295629003953, pvalue=0.011844126429238239)
# data_mckoon 7 : Ttest_relResult(statistic=2.315977610100544, pvalue=0.027342325220756084)
# data_mckoon 8 : Ttest_relResult(statistic=2.0779747800837884, pvalue=0.04608203509259067)
# data_mckoon 9 : Ttest_relResult(statistic=2.6783214213038278, pvalue=0.011729610520715267)
# ...

# %%
print("pearsonr(MetusalemSemantics, MetusalemInference)")
print(pearsonr(MetusalemSemantics, MetusalemInference))
print("pearsonr(MetusalemSemantics, McKoonInference)")
print(pearsonr(MetusalemSemantics, McKoonInference))

print("pearsonr(MetusalemSemantics_leaky, MetusalemInference_leaky)")
print(pearsonr(MetusalemSemantics_leaky, MetusalemInference_leaky))
print("pearsonr(MetusalemSemantics_leaky, McKoonInference_leaky)")
print(pearsonr(MetusalemSemantics_leaky, McKoonInference_leaky))


print("pearsonr(MetusalemInference, McKoonInference)")
print(pearsonr(MetusalemInference, McKoonInference))
#print("pearsonr(MetusalemInference_bert, McKoonInference_bert)")
#print(pearsonr(MetusalemInference_bert, McKoonInference_bert))

print("pearsonr(MetusalemInference_leaky, McKoonInference_leaky)")
print(pearsonr(MetusalemInference_leaky, McKoonInference_leaky))


plt.scatter(MetusalemSemantics, MetusalemInference, label='Met-inf', color='red')
plt.scatter(MetusalemSemantics, McKoonInference, label='Mc-inf', color='blue')

plt.scatter(MetusalemSemantics_leaky, MetusalemInference_leaky, label='Met-inf-leaky', color='orange')
plt.scatter(MetusalemSemantics_leaky, McKoonInference_leaky, label='Mc-inf-leaky', color='green')


#plt.scatter(MetusalemSemantics_bert, MetusalemInference_bert, label='Met-inf-bert', color='orange')
#plt.scatter(MetusalemSemantics_bert, McKoonInference_bert, label='Mc-inf-bert', color='green')

coefficientMetusalem = np.polyfit(MetusalemSemantics, MetusalemInference, 1)
coefficientMcKoon = np.polyfit(MetusalemSemantics, McKoonInference, 1)
print("coefficientMetusalem")
print(coefficientMetusalem)
print("coefficientMcKoon")
print(coefficientMcKoon)


coefficientMetusalem_leaky = np.polyfit(MetusalemSemantics_leaky, MetusalemInference_leaky, 1)
coefficientMcKoon_leaky = np.polyfit(MetusalemSemantics_leaky, McKoonInference_leaky, 1)
print("coefficientMetusalem_leaky")
print(coefficientMetusalem_leaky)
print("coefficientMcKoon_leaky")
print(coefficientMcKoon_leaky)


#coefficientMetusalem_bert = np.polyfit(MetusalemSemantics_bert, MetusalemInference_bert, 1)
#coefficientMcKoon_bert = np.polyfit(MetusalemSemantics_bert, McKoonInference_bert, 1)
#print("coefficientMetusalem_bert")
#print(coefficientMetusalem_bert)
#print("coefficientMcKoon_bert")
#print(coefficientMcKoon_bert)

plt.plot(MetusalemSemantics, np.poly1d(coefficientMetusalem)(MetusalemSemantics), color='red')
plt.plot(MetusalemSemantics, np.poly1d(coefficientMcKoon)(MetusalemSemantics), color='blue')


plt.plot(MetusalemSemantics_leaky, np.poly1d(coefficientMetusalem_leaky)(MetusalemSemantics_leaky), color='orange')
plt.plot(MetusalemSemantics_leaky, np.poly1d(coefficientMcKoon_leaky)(MetusalemSemantics_leaky), color='green')

plt.xlabel('t-score for Semantics (Metusalem)')
plt.ylabel('t-score for Inference')

#plt.plot(MetusalemSemantics_bert, np.poly1d(coefficientMetusalem_bert)(MetusalemSemantics_bert), color='orange')
#plt.plot(MetusalemSemantics_bert, np.poly1d(coefficientMcKoon_bert)(MetusalemSemantics_bert), color='green')

plt.legend()
plt.show()
# Out:
# pearsonr(MetusalemSemantics, MetusalemInference)
# (0.9146357632669315, 2.5977020102299e-09)
# pearsonr(MetusalemSemantics, McKoonInference)
# (0.478354051743145, 0.024325306770971528)
# pearsonr(MetusalemSemantics_leaky, MetusalemInference_leaky)
# (0.9129787314909049, 3.12628544066519e-09)
# pearsonr(MetusalemSemantics_leaky, McKoonInference_leaky)
# (0.21015683695682158, 0.3478713508620531)
# pearsonr(MetusalemInference, McKoonInference)
# (0.4654666514186174, 0.02903230922422777)
# pearsonr(MetusalemInference_leaky, McKoonInference_leaky)
# (0.18424815572262365, 0.4117500936634207)
# coefficientMetusalem
# [ 0.739886 -0.626073]
# coefficientMcKoon
# [0.070283 1.844839]
# coefficientMetusalem_leaky
# [ 0.688969 -0.587219]
# coefficientMcKoon_leaky
# [0.036625 1.833272]

# %%
plt.scatter(MetusalemInference, McKoonInference, label='average', color='red')
#plt.scatter(MetusalemInference_bert, McKoonInference_bert, label='bert', color='blue')
plt.scatter(MetusalemInference_leaky, McKoonInference_leaky, label='leaky integrator', color='blue')

plt.xlabel('MetusalemInference')
plt.ylabel('McKoonInference')

plt.legend()
plt.show()
