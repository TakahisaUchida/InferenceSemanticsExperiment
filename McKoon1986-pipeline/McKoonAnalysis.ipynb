# %%
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib import pyplot
import nltk

import csv

import scipy
from scipy import stats

# %%
# this is the 50 reservoir data
data = [[0.56594987, 0.56658663, 0.56815967, 0.56130783, 0.56601341,
       0.5675054 , 0.5698067 , 0.56944568, 0.56631777, 0.5753933 ,
       0.57101363, 0.56863287, 0.56799745, 0.57037079, 0.56608213,
       0.57150765, 0.57047349, 0.56454614, 0.57078241, 0.56534325,
       0.55923829, 0.56638531, 0.56688956, 0.56824328, 0.57839981,
       0.56363789, 0.56911   , 0.56390943, 0.57189565, 0.57037613,
       0.56839871, 0.57116399, 0.57516919, 0.57099125, 0.56120379,
       0.56864256, 0.56437984, 0.57200057, 0.56499303, 0.56529831,
       0.56626218, 0.57141575, 0.56920249, 0.56807821, 0.5681024 ,
       0.56278277, 0.57119376, 0.57261772, 0.56713015, 0.56098459], [0.56547021, 0.56721987, 0.56595998, 0.56246206, 0.56603037,
       0.56590079, 0.56628995, 0.56387064, 0.55970943, 0.56976403,
       0.56536231, 0.56626925, 0.56323702, 0.57066733, 0.56312932,
       0.5718598 , 0.56873951, 0.56327474, 0.5672621 , 0.56327457,
       0.56276641, 0.56302488, 0.56662996, 0.56300388, 0.57299573,
       0.56270063, 0.56456372, 0.56777131, 0.5712204 , 0.56713471,
       0.56837255, 0.56630314, 0.57258584, 0.57165107, 0.56287645,
       0.56356948, 0.57067076, 0.56536704, 0.56604487, 0.56326356,
       0.56242023, 0.56967345, 0.56621858, 0.5724119 , 0.56471165,
       0.5620626 , 0.56792539, 0.57206488, 0.56572791, 0.55918044]]

# %%
print(len(data[0]))
# Out:
# 50

# %%
print('t-test: for A vs B: ', stats.ttest_ind(data[0], data[1]))
# Out:
# t-test: for A vs B:  Ttest_indResult(statistic=2.4863164561427213, pvalue=0.014598577290380168)

# %%
# Create a figure instance
fig = plt.figure(1, figsize=(9, 5))
fig = plt.figure(1)
# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data)

ax.set_xticklabels(['Inference', 'Control'])
#plt.title('Context 1            Context 2')
plt.xlabel('Target words and Infernce vs Control')
plt.ylabel('Semantic Relatedness')
fig.tight_layout()
plt.savefig('McKoon-50-res.png')
plt.show()

# %%
fig= plt.figure(figsize=(8,5))
plt.hist(data[0], 8, alpha=0.5, label='Infernce')
plt.hist(data[1], 8, alpha=0.5, label='Control')

# Add title and axis names
plt.title('Relatedness Distributions')
plt.xlabel('Semantic Relatedness')
plt.ylabel('Instances')
plt.legend(loc='best')

plt.savefig('McKoon-50-Res-HisT-before.png')

plt.show()

# %%
fig= plt.figure(figsize=(12,5))
# Cut your window in 1 row and 2 columns, and start a plot in the first part
plt.subplot(121)

plt.hist(data[0], 8, alpha=0.5, label='Infernce')
plt.hist(data[1], 8, alpha=0.5, label='Control')

# Add title and axis names
plt.title('Lexical Inference Distributions')
plt.xlabel('Semantic Relatedness')
plt.ylabel('Instances')
plt.legend(loc='best')

 
# And now add something in the second part:
ax = fig.add_subplot(122)


# Create the boxplot
bp = ax.boxplot(data)

ax.set_xticklabels(['Inference', 'Control'])
plt.title('Lexical Inference Medians')
plt.xlabel('Conditions')
plt.ylabel('Semantic Relatedness')
fig.tight_layout()

plt.savefig('McKoon-50-Res-RADICAL.png')

# %%
import csv
f = open('TILL-50-reservoirs.csv', 'w')
writer = csv.writer(f, lineterminator='\n')

# %%
for i in range(50):
    writer.writerow([data[0][i], data[1][i], data[2][i], data[3][i], data[4][i], data[5][i], data[6][i], data[7][i]])

# %%
f.close()

# %%
fig= plt.figure(figsize=(18,6))
# Cut your window in 1 row and 2 columns, and start a plot in the first part
plt.subplot(131)

plt.hist(data[0], 8, alpha=0.5, label='Assoc-1')
plt.hist(data[1], 8, alpha=0.5, label='Inf-1')
plt.hist(data[2], 8, alpha=0.5, label='Assoc-2')
plt.hist(data[3], 8, alpha=0.5, label='Inf-2')

# Add title and axis names
plt.title('Context 1')
plt.xlabel('Semantic Relatedness')
plt.ylabel('Instances')
plt.legend(loc='best')
plt.xlim(0.49, 0.59)
plt.ylim(0, 18)
 
# And now add something in the second part:
plt.subplot(132)

plt.hist(data[4], 8, alpha=0.5, label='Assoc-1')
plt.hist(data[5], 8, alpha=0.5, label='Inf-1')
plt.hist(data[6], 8, alpha=0.5, label='Assoc-2')
plt.hist(data[7], 8, alpha=0.5, label='Inf-2')

# Add title and axis names
plt.title('Context 2')
plt.xlabel('Semantic Relatedness')
plt.ylabel('Instances')
plt.legend(loc='best')

plt.xlim(0.49, 0.59)
plt.ylim(0, 18)
 
# now 

ax = fig.add_subplot(133)


# Create the boxplot
bp = ax.boxplot(data)

ax.set_xticklabels(['Assoc-1', 'Inf-1', 'Assoc-2', 'Inf-2', 'Assoc-1', 'Inf-1', 'Assoc-2', 'Inf-2'])
plt.title('Context 1            Context 2')
plt.xlabel('Target words in Sentence vs Discourse')
plt.ylabel('Semantic Relatedness')
fig.tight_layout()

plt.savefig('Till-50-Res-RADICAL.png')

# %%
# this is data for the target word from the discourse compared to the four target words
data1 = [[0.38325894, 0.55214167, 0.16708051, 0.29310319, 0.43932149,
       0.46370205, 0.4231039 , 0.54485941, 0.48946476, 0.89098626,
       0.31301242, 0.31905285, 0.39426443, 0.40603918, 0.47889096,
       0.41319966, 0.60542238, 0.58773285, 0.67277592, 0.42488363,
       0.48965678, 0.55050218, 0.59978241, 0.51799995, 0.63158852,
       0.3627294 , 0.24021429, 0.38625664], [0.27987888, 0.54364723, 0.18167011, 0.41059175, 0.34204066,
       0.29720953, 0.26094833, 0.27828488, 0.36942473, 0.31834808,
       0.38888332, 0.26520184, 0.32250533, 0.40992033, 0.38664636,
       0.33777934, 0.4638252 , 0.29676953, 0.53391171, 0.20928611,
       0.2336643 , 0.50655848, 0.4850609 , 0.42581844, 0.20477311,
       0.22853564, 0.49177492, 0.50736934], [0.52398646, 0.43253845, 0.41621527, 0.63111389, 0.5307833 ,
       0.27179527, 0.45824698, 0.51696658, 0.28496936, 0.40837678,
       0.75446916, 0.49598435, 0.36360702, 0.32114142, 0.21224743,
       0.39436054, 0.60163999, 0.24046443, 0.49384344, 0.500826  ,
       0.230964  , 0.44152594, 0.55214167, 0.59923917, 0.54076058,
       0.46675476, 0.5732165 , 0.39015526], [0.28602791, 0.23743346, 0.16860157, 0.21075641, 0.34339622,
       0.339564  , 0.35125878, 0.5264926 , 0.28010473, 0.24786155,
       0.37258786, 0.30578029, 0.23009065, 0.23773482, 0.20602037,
       0.36739907, 0.32373014, 0.24543434, 0.23850028, 0.53033072,
       0.19067909, 0.34028584, 0.2970241 , 0.31289983, 0.31129611,
       0.3467055 , 0.33113736, 0.32783207]]

# %%
data2 = data + data1
data2 = [data1[0]]
# Create a figure instance
#fig = plt.figure(1, figsize=(15,5))
fig = plt.figure(1)
# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot( data1)

ax.set_xticklabels(['Assoc-1', 'Inf-1', 'Assoc-2', 'Inf-2'])
plt.title('Single Word Compared to 4 Targets')
plt.xlabel('Target words in Sentence vs Discourse')
plt.ylabel('Semantic Relatedness')
fig.tight_layout()
plt.savefig('Till-words-avg.png')
plt.show()

# %%
print('t-test: for A1 vs I1: ', stats.ttest_ind(data1[0], data1[1]))
print('t-test: for A2 vs I2: ', stats.ttest_ind(data1[2], data1[3]))
# Out:
# t-test: for A1 vs I1:  Ttest_indResult(statistic=3.1684116357670584, pvalue=0.0025232478543076695)
# t-test: for A2 vs I2:  Ttest_indResult(statistic=4.989103532793839, pvalue=6.662010582588112e-06)

# %%
fig= plt.figure(figsize=(8,5))
plt.hist(data[0], 8, alpha=0.5, label='Assoc-1')
plt.hist(data[1], 8, alpha=0.5, label='Inf-1')
plt.hist(data[2], 8, alpha=0.5, label= 'Assoc-2')
plt.hist(data[3], 8, alpha=0.5, label='Inf-2')

# Add title and axis names
plt.title('Relatedness Distributions')
plt.xlabel('Semantic Relatedness')
plt.ylabel('Instances')
plt.legend(loc='best')

plt.savefig('Till-Hist-simple-words.png')

plt.show()

# %%
#this is for one reservoir, 28 scenarios
data=[[0.52043079, 0.49340993, 0.50856195, 0.57867632, 0.54729063,
       0.57067006, 0.54309268, 0.59035866, 0.56501399, 0.76168013,
       0.60596688, 0.61348901, 0.53214289, 0.62698036, 0.58681683,
       0.56285858, 0.61578873, 0.53715124, 0.57855918, 0.58728891,
       0.63569345, 0.64109132, 0.59570084, 0.61139998, 0.65065143,
       0.51066688, 0.52859559, 0.54753495], [0.46678847, 0.67843426, 0.48276327, 0.59901511, 0.52232312,
       0.51178288, 0.49641594, 0.49814615, 0.59993426, 0.522697  ,
       0.59422924, 0.60275968, 0.58368082, 0.54588809, 0.50744589,
       0.61973958, 0.53055549, 0.55629324, 0.53378232, 0.48455329,
       0.49033809, 0.65555834, 0.56563086, 0.60433595, 0.45733907,
       0.52200625, 0.61180455, 0.52446416], [0.53087402, 0.52247441, 0.6325113 , 0.59602319, 0.55557729,
       0.50493713, 0.50107921, 0.50707111, 0.51570972, 0.46073236,
       0.59811851, 0.54648237, 0.58475943, 0.62637197, 0.46052242,
       0.47423529, 0.62333707, 0.5290916 , 0.51195913, 0.42939156,
       0.43444779, 0.5244348 , 0.59251154, 0.58227329, 0.5665164 ,
       0.54619068, 0.64959467, 0.46184624], [0.45239636, 0.49559187, 0.47204102, 0.52820795, 0.50488694,
       0.46450778, 0.50648326, 0.49643596, 0.56031262, 0.45184247,
       0.62250091, 0.44659761, 0.4899362 , 0.40760413, 0.48343044,
       0.46219567, 0.54386128, 0.4193227 , 0.43944358, 0.65680984,
       0.44952744, 0.45860658, 0.5660161 , 0.51355254, 0.49542078,
       0.5218672 , 0.45389822, 0.5249904 ], [0.55564673, 0.50973815, 0.47970395, 0.58487236, 0.56878886,
       0.5878745 , 0.53840867, 0.60854621, 0.57840826, 0.77048629,
       0.57713713, 0.57015453, 0.50896467, 0.58507972, 0.65013566,
       0.53532296, 0.55398237, 0.52343044, 0.59747591, 0.5168991 ,
       0.48572773, 0.59452326, 0.60883451, 0.59660802, 0.61424785,
       0.455558  , 0.50317878, 0.53905119], [0.42126842, 0.67747122, 0.44759816, 0.53967931, 0.49737696,
       0.48554877, 0.45098948, 0.53296978, 0.57261284, 0.50802631,
       0.61131216, 0.59968669, 0.58288019, 0.54898195, 0.44015387,
       0.55824127, 0.48438227, 0.52035604, 0.51471535, 0.39728647,
       0.499163  , 0.60345023, 0.52835759, 0.58369209, 0.4510627 ,
       0.50722738, 0.62464198, 0.49333227], [0.60027305, 0.54094568, 0.60234403, 0.61086366, 0.58281426,
       0.49684298, 0.57280645, 0.52281023, 0.49566547, 0.48156529,
       0.64431172, 0.57406026, 0.60661623, 0.63724036, 0.54564624,
       0.55333384, 0.62242919, 0.55110408, 0.52345739, 0.44953732,
       0.38854006, 0.56141134, 0.58585005, 0.59871571, 0.58113694,
       0.56425762, 0.59781265, 0.52769281], [0.4991885 , 0.50718854, 0.54300693, 0.49411966, 0.49332037,
       0.54097065, 0.59565628, 0.57449061, 0.58328284, 0.44265154,
       0.60506489, 0.50473528, 0.51689848, 0.45844797, 0.50950431,
       0.53754587, 0.56699779, 0.44809131, 0.45374749, 0.69437867,
       0.51809887, 0.46709827, 0.57527189, 0.52878055, 0.5255659 ,
       0.54840447, 0.49030078, 0.54992924]]

# %%
# this is for the single reservoir
fig= plt.figure(figsize=(18,6))
# Cut your window in 1 row and 2 columns, and start a plot in the first part
plt.subplot(131)

plt.hist(data[0], 8, alpha=0.5, label='Assoc-1')
plt.hist(data[1], 8, alpha=0.5, label='Inf-1')
plt.hist(data[2], 8, alpha=0.5, label='Assoc-2')
plt.hist(data[3], 8, alpha=0.5, label='Inf-2')

# Add title and axis names
plt.title('Context 1')
plt.xlabel('Semantic Relatedness')
plt.ylabel('Instances')
plt.legend(loc='best')
plt.xlim(0.40, 0.80)
plt.ylim(0, 12)
 
# And now add something in the second part:
plt.subplot(132)

plt.hist(data[4], 8, alpha=0.5, label='Assoc-1')
plt.hist(data[5], 8, alpha=0.5, label='Inf-1')
plt.hist(data[6], 8, alpha=0.5, label='Assoc-2')
plt.hist(data[7], 8, alpha=0.5, label='Inf-2')

# Add title and axis names
plt.title('Context 2')
plt.xlabel('Semantic Relatedness')
plt.ylabel('Instances')
plt.legend(loc='best')

plt.xlim(0.40, 0.80)
plt.ylim(0, 12)
 
# now 

ax = fig.add_subplot(133)


# Create the boxplot
bp = ax.boxplot(data)

ax.set_xticklabels(['Assoc-1', 'Inf-1', 'Assoc-2', 'Inf-2', 'Assoc-1', 'Inf-1', 'Assoc-2', 'Inf-2'])
plt.title('Context 1            Context 2')
plt.xlabel('Target words in Sentence vs Discourse')
plt.ylabel('Semantic Relatedness')
fig.tight_layout()

plt.savefig('Till-1-Res-RADICAL.png')

# %% [markdown]
# #graphic

# %%
#heatmap!!

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Define numbers of generated data points and bins per axis.

N_bins = 10


# Construct 2D histogram from data using the 'plasma' colormap
plt.hist2d(data[1], data[4], bins=N_bins, density=False, cmap='plasma')

# Plot a colorbar with label.
cb = plt.colorbar()
cb.set_label('Number of entries')

# Add title and labels to plot.
plt.title('Heatmap of 2D normally distributed data points')
plt.xlabel('x axis')
plt.ylabel('y axis')

# Show the plot.
plt.show()
